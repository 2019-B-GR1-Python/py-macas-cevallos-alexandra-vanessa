# %%
import os
print("hola, que ma pue")
def menu():
    
    os.system('clear') 
    print ("Selecciona una opción")
    print ("\t1 - Paciente")
    print ("\t2 - Medicina")
    print ("\t3 - Salir")

def menu_paciente():
    
    os.system('clear') 
    print ("Selecciona una opción")
    print ("\t1 - Nuevo Paciente")
    print ("\t2 - Consultar Pacientes")
    print ("\t3 - Modificar Paciente")
    print ("\t4 - Eliminar Paciente")
    print ("\t5 - Salir")

def menu_medicina():
    
    os.system('clear') 
    print ("Selecciona una opción") 
    print ("\t1 - Nueva Medicina")
    print ("\t2 - Consultar Medicinas")
    print ("\t3 - Modificar Medicina")
    print ("\t4 - Eliminar Medicina")
    print ("\t5 - Salir")    

while True:
  
    menu()
    opcionMenu = input("Escoje una opcion del menu: ")
    
    if opcionMenu=="1":
        menu_paciente()
        opcionMenuPaciente = input("Escoje una opcion del menu: ")
        
        if opcionMenuPaciente=="1":
            print ("")     
            nombre_paciente = input("Ingrese nombre del paciente: ")
            edad_paciente = input("Ingrese edad del paciente: ")
            sexo_paciente = input("Ingrese sexo del paciente: ")
       
        
            try:
                path = "./bd_paciente.txt"
                archivo_abierto_escritura = open(path,mode="a")
                archivo_abierto_escritura.write(f"{nombre_paciente}, ")
                archivo_abierto_escritura.write(f"{edad_paciente}, ")
                archivo_abierto_escritura.write(f"{sexo_paciente}\n")
                archivo_abierto_escritura.close()
            except Exception as error:
                print('error de paciente')
            
        elif opcionMenuPaciente=="2":
            print ("")
            try:
                path = "./bd_paciente.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                for linea in contenido:
                    print(linea)
                archivo_abierto.close()
            except Exception as error:
                print('error paciente')   
        elif opcionMenuPaciente=="3":
            print ("")
            try:
                path = "./bd_paciente.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                archivo_abierto.close()
                archivo_abierto = open(path,mode="w")
            
                for linea in contenido:
                    print(linea)
                linea_eliminar = input("Ingrese los datos del paciente a modificar: ")
                linea_agregar = input("Ingrese los datos del paciente modificado: ")
                for linea in contenido:
                    if linea != f"{linea_eliminar}\n":
                        archivo_abierto.write(f"{linea}")
                    else:
                        archivo_abierto.write(f"{linea_agregar}\n")
                archivo_abierto.close()
            except Exception as error:
                print('error')
        elif opcionMenuPaciente=="4":
            print ("")
            try:
                path = "./bd_paciente.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                archivo_abierto.close()
                archivo_abierto = open(path,mode="w")
            
                for linea in contenido:
                    print(linea)
                linea_eliminar = input("Ingrese los datos del paciente a eliminar: ")
                for linea in contenido:
                    if linea != f"{linea_eliminar}\n":
                        archivo_abierto.write(f"{linea}")
                archivo_abierto.close()
            except Exception as error:
                print('error paciente')
        elif opcionMenuPaciente=="5":
            break
        
        else:
            print ("")
            input("No has seleccionado una opcion...\n Selecciona una opcion del menu")   
    
    elif opcionMenu=="2":
        menu_medicina()
        opcionMenuMedicina = input("Escoje una opcion del menu: ")
        if opcionMenuMedicina=="1":
        
            print ("")
            nombre_medicamento = input("Ingrese el nombre del medicamento: ")
            tipo_medicamento = input("Ingrese tipo de medicamento: ")
            cantidad_medicamento = input("Ingrese la cantidad del medicamento: ")
       
        
            try:
                path = "./bd_medicamento.txt"
                archivo_abierto_escritura = open(path,mode="a")
                archivo_abierto_escritura.write(f"{nombre_medicamento}, ")
                archivo_abierto_escritura.write(f"{tipo_medicamento}, ")
                archivo_abierto_escritura.write(f"{cantidad_medicamento}\n")
                archivo_abierto_escritura.close()
            except Exception as error:
                print('error medicamento')
            
        elif opcionMenuMedicina=="2":
            print ("")
            try:
                path = "./bd_medicamento.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                for linea in contenido:
                    print(linea)
                archivo_abierto.close()
            except Exception as error:
                print('error medicamento')
    
        elif opcionMenuMedicina=="3":
            print ("")
            try:
                path = "./bd_medicamento.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                archivo_abierto.close()
                archivo_abierto = open(path,mode="w")
            
                for linea in contenido:
                    print(linea)
                linea_eliminar = input("Ingrese el medicamento a modificar: ")
                linea_agregar = input("Ingrese el medicamento modificado: ")
                for linea in contenido:
                    if linea != f"{linea_eliminar}\n":
                        archivo_abierto.write(f"{linea}")
                    else:
                        archivo_abierto.write(f"{linea_agregar}\n")
                archivo_abierto.close()
            except Exception as error:
                print('error medicamento')

        elif opcionMenuMedicina=="4":
            print ("")
            try:
                path = "./bd_medicamento.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                archivo_abierto.close()
                archivo_abierto = open(path,mode="w")
            
                for linea in contenido:
                    print(linea)
                linea_eliminar = input("Ingrese los datos del medicamento a eliminar: ")
                for linea in contenido:
                    if linea != f"{linea_eliminar}\n":
                        archivo_abierto.write(f"{linea}")
                archivo_abierto.close()
            except Exception as error:
                print('error medicamento')
        
        
        elif opcionMenuMedicina=="5":
            break
        
        
        else:
            print ("")
            input("No has seleccionado una opcion...\n Selecciona una opcion del menu") 
     
    
    elif opcionMenu=="3":
        break
    else:
        print ("")
        input("No has seleccionado una opcion...\n Selecciona una opcion del menu")
# Out:
# hola, que ma pue
# Selecciona una opción
# 	1 - Paciente
# 	2 - Medicina
# 	3 - Salir
# Escoje una opcion del menu: 1
# Selecciona una opción
# 	1 - Nuevo Paciente
# 	2 - Consultar Pacientes
# 	3 - Modificar Paciente
# 	4 - Eliminar Paciente
# 	5 - Salir
# Escoje una opcion del menu: 3
#
# Angel Daniel, 23, Masculino
#
# Alexandra, 26, femenino
#
# Ingrese los datos del paciente a modificar: Alexandra, 26, femenino
# Ingrese los datos del paciente modificado: Ale, 26, femenino
# Selecciona una opción
# 	1 - Paciente
# 	2 - Medicina
# 	3 - Salir
# Escoje una opcion del menu: 2
# Selecciona una opción
# 	1 - Nueva Medicina
# 	2 - Consultar Medicinas
# 	3 - Modificar Medicina
# 	4 - Eliminar Medicina
# 	5 - Salir
# Escoje una opcion del menu: 2
#
# Paracetamol, Generico, 2
#
# Selecciona una opción
# 	1 - Paciente
# 	2 - Medicina
# 	3 - Salir
# Escoje una opcion del menu: 1
# Selecciona una opción
# 	1 - Nuevo Paciente
# 	2 - Consultar Pacientes
# 	3 - Modificar Paciente
# ...
